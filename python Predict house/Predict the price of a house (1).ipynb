# %%
# all assumptions and the rationale behind them Mention  below:-
#Distance from nearest Metro station (km) 
#

# %%
#importing libraries in python
import pandas as pd
import numpy as np
import streamlit as st

# %%
# Creating variables from dataset of column
data = pd.read_excel("DS - Assignment Part 1 data set.xlsx")
date = data['Transaction date']
age =  data['House Age']
stores=data['Number of convenience stores']
bedrooms=data['Number of bedrooms']
size=data['House size (sqft)']
unitp=data['House price of unit area']
price = data['Price of House']
data
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0         2012.916667       32.0                                  84.87882
# 1         2012.916667       19.5                                 306.59470
# 2         2013.583333       13.3                                 561.98450
# 3         2013.500000       13.3                                 561.98450
# 4         2012.833333        5.0                                 390.56840
# ..                ...        ...                                       ...
# 409       2013.000000       13.7                                4082.01500
# 410       2012.666667        5.6                                  90.45606
# 411       2013.250000       18.8                                 390.96960
# 412       2013.000000        8.1                                 104.81010
# 413       2013.500000        6.5                                  90.45606
#
# ...

# %%
#model based on area of house 
area=int(input('Enter area of house:'))
areap=price.mean()
areahome = areap* area
print ("the price of your house is :",home)

# %%
#model based on Number of convenience stores around house 
area=int(input('Enter area of house:'))
areap=price.mean()
areahome = areap* area
print ("the price of your house is :",home)
