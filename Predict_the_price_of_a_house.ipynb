# %%
#importing libraries in python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Out:
# Mounted at /content/drive

# %%
# Creating variables from dataset of column
data = pd.read_excel("https://github.com/yashsahu27420/python-Predict-house/blob/main/DS%20-%20Assignment%20Part%201%20data%20set.xlsx?raw=true")
stores=data['Number of convenience stores']
size=data['House size (sqft)']
la=data['latitude']
lo=data['longitude']
unitp=data['House price of unit area']
data.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area  Price of House
# ...

# %%
#Statistics table of data
data.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
plt.scatter(la,lo,alpha=0.9,s=50)

# %%
#taking input from buyer of house

area=int(input('Enter area of house(sq ft):'))
ag= int(input('Enter age of house:'))
bedroom= int(input('Enter Number of bedrooms:'))
la= (input('Enter latitude:')) 
la = float(la)
lo=(input('Enter longitude:'))
lo= float(lo)
# Out:
# Enter area of house(sq ft):963
# Enter age of house:6
# Enter Number of bedrooms:2
# Enter latitude:24.969
# Enter longitude:121.533

# %%
#model based on average price and area of house 
areap=unitp.mean()
price = areap* area
price=int(price)
print ("The price of your house is based on average price and area of house is RS:",price)
# Out:
# The price of your house is based on average price and area of house is RS: 36574

# %%
#model based on age of house
#assumption:- the life time usage of a house is 100 year 
areap=unitp.mean()
g=100-ag
#depreciation house valueon base of  age factor
age=price/100

ageprice =age*g
print ("The price of your house based on age of house is RS :",int(ageprice))
# Out:
# The price of your house based on age of house is RS : 34379

# %%
#providing a  inflating house prices due to  latitude and longitude based on scatter graph analysis and Statistics table
iprice= price
p= price + 10*100
if la>=24.963 and  la<=24.977 and lo>= 121.5280    and  lo<=121.5433  :
  iprice= price + 30*100
  print ("The price of your inflated house prices by 30%  due to area :",int(iprice))
else :
  print("The price of your house is RS :",price)
# Out:
# The price of your inflated house prices by 30%  due to area : 39574

# %%
#The final price of the house is average of all 3 method
finalprice= (iprice + ageprice + price)/3
#providing a suggestion based on general understanding of house

if area<=1000 and bedroom==3:
  print ("house is not suitable for 3 bhk ")
elif area<=500 and bedroom==2:
  print ("house is not suitable for 2 bhk ")
elif area<=400 and bedroom==1:
  print ("house is not suitable for 1 bhk ")
else :
  print("you can buy this house based on area and number of room and")
print ("The final price of your house is RS",int(finalprice))
# Out:
# you can buy this house based on area and number of room and
# The final price of your house is RS 36842

# %%
#Predict the price of a house 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
 
# Read Images
img = mpimg.imread('/Folder/(1).jpeg')
 
# Output Images
plt.imshow(img)
